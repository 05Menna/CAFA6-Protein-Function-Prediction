# %%
import sys
sys.path.append('..')

# %%
from src.data.data_loader import load_protein_sequences

# %%
sequences = load_protein_sequences('../data/raw/Train/train_sequences.fasta')
print(f"Loaded {len(sequences)} sequences")
# Out:
# ✓ Loaded 82404 protein sequences
# Loaded 82404 sequences
